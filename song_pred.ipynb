# %%
import pandas as pd
import numpy as np
import matplotlib
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
#from surprise import Dataset, Reader, SVD
#from surprise.model_selection import train_test_split
#from surprise import accuracy

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.2

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
songs = pd.read_csv('songs.csv')
song_extra_info = pd.read_csv('song_extra_info.csv')
members = pd.read_csv('members.csv')

# %%
# Добавим к тренировочным и тестовым данным информацию о песнях и пользователях

train = train.merge(songs, on='song_id', how='left')
train = train.merge(members, on='msno', how='left')

test = test.merge(songs, on='song_id', how='left')
test = test.merge(members, on='msno', how='left')

# %%
train = train.merge(song_extra_info, on='song_id', how='left')
test = test.merge(song_extra_info, on='song_id', how='left')

# %%
def values_info(data):
    dtypes = pd.DataFrame(data.dtypes,columns=['Data Type'])
    dtypes['Unique Values']=data.nunique().sort_values(ascending=True)
    dtypes['Null Values']=data.isnull().sum()
    dtypes['% null Values']=data.isnull().sum()/len(data)
    return dtypes.sort_values(by='Null Values' , ascending=False).style.background_gradient()

# %%
values_info(train)
# Out:
# <style type="text/css">
# #T_ff735_row0_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_ff735_row0_col2, #T_ff735_row0_col3, #T_ff735_row13_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ff735_row1_col1, #T_ff735_row4_col1, #T_ff735_row5_col1, #T_ff735_row6_col1, #T_ff735_row7_col1, #T_ff735_row8_col2, #T_ff735_row8_col3, #T_ff735_row9_col1, #T_ff735_row9_col2, #T_ff735_row9_col3, #T_ff735_row10_col2, #T_ff735_row10_col3, #T_ff735_row11_col2, #T_ff735_row11_col3, #T_ff735_row12_col1, #T_ff735_row12_col2, #T_ff735_row12_col3, #T_ff735_row13_col2, #T_ff735_row13_col3, #T_ff735_row14_col1, #T_ff735_row14_col2, #T_ff735_row14_col3, #T_ff735_row15_col1, #T_ff735_row15_col2, #T_ff735_row15_col3, #T_ff735_row16_col1, #T_ff735_row16_col2, #T_ff735_row16_col3, #T_ff735_row17_col2, #T_ff735_row17_col3, #T_ff735_row18_col1, #T_ff735_row18_col2, #T_ff735_row18_col3, #T_ff735_row19_col2, #T_ff735_row19_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ff735_row1_col2, #T_ff735_row1_col3 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_ff735_row2_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_ff735_row2_col2, #T_ff735_row2_col3 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_ff735_row3_col1 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_ff735_row3_col2, #T_ff735_row3_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_ff735_row4_col2, #T_ff735_row4_col3 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_ff735_row5_col2, #T_ff735_row5_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_ff735_row6_col2, #T_ff735_row6_col3, #T_ff735_row17_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_ff735_row7_col2, #T_ff735_row7_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_ff735_row8_col1 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_ff735_row10_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_ff735_row11_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_ff735_row19_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# </style>
# <table id="T_ff735">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff735_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_ff735_level0_col1" class="col_heading level0 col1" >Unique Values</th>
#       <th id="T_ff735_level0_col2" class="col_heading level0 col2" >Null Values</th>
#       <th id="T_ff735_level0_col3" class="col_heading level0 col3" >% null Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff735_level0_row0" class="row_heading level0 row0" >lyricist</th>
#       <td id="T_ff735_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_ff735_row0_col1" class="data row0 col1" >33887</td>
#       <td id="T_ff735_row0_col2" class="data row0 col2" >3178812</td>
#       <td id="T_ff735_row0_col3" class="data row0 col3" >0.430884</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row1" class="row_heading level0 row1" >gender</th>
#       <td id="T_ff735_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_ff735_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_ff735_row1_col2" class="data row1 col2" >2961479</td>
#       <td id="T_ff735_row1_col3" class="data row1 col3" >0.401425</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row2" class="row_heading level0 row2" >composer</th>
#       <td id="T_ff735_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_ff735_row2_col1" class="data row2 col1" >76064</td>
#       <td id="T_ff735_row2_col2" class="data row2 col2" >1675706</td>
#       <td id="T_ff735_row2_col3" class="data row2 col3" >0.227140</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row3" class="row_heading level0 row3" >isrc</th>
#       <td id="T_ff735_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_ff735_row3_col1" class="data row3 col1" >269760</td>
#       <td id="T_ff735_row3_col2" class="data row3 col2" >577858</td>
#       <td id="T_ff735_row3_col3" class="data row3 col3" >0.078328</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row4" class="row_heading level0 row4" >source_screen_name</th>
#       <td id="T_ff735_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_ff735_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_ff735_row4_col2" class="data row4 col2" >414804</td>
#       <td id="T_ff735_row4_col3" class="data row4 col3" >0.056226</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row5" class="row_heading level0 row5" >genre_ids</th>
#       <td id="T_ff735_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_ff735_row5_col1" class="data row5 col1" >572</td>
#       <td id="T_ff735_row5_col2" class="data row5 col2" >118455</td>
#       <td id="T_ff735_row5_col3" class="data row5 col3" >0.016056</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row6" class="row_heading level0 row6" >source_system_tab</th>
#       <td id="T_ff735_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_ff735_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_ff735_row6_col2" class="data row6 col2" >24849</td>
#       <td id="T_ff735_row6_col3" class="data row6 col3" >0.003368</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row7" class="row_heading level0 row7" >source_type</th>
#       <td id="T_ff735_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_ff735_row7_col1" class="data row7 col1" >12</td>
#       <td id="T_ff735_row7_col2" class="data row7 col2" >21539</td>
#       <td id="T_ff735_row7_col3" class="data row7 col3" >0.002920</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row8" class="row_heading level0 row8" >name</th>
#       <td id="T_ff735_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_ff735_row8_col1" class="data row8 col1" >234144</td>
#       <td id="T_ff735_row8_col2" class="data row8 col2" >1457</td>
#       <td id="T_ff735_row8_col3" class="data row8 col3" >0.000197</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row9" class="row_heading level0 row9" >language</th>
#       <td id="T_ff735_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_ff735_row9_col1" class="data row9 col1" >10</td>
#       <td id="T_ff735_row9_col2" class="data row9 col2" >150</td>
#       <td id="T_ff735_row9_col3" class="data row9 col3" >0.000020</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row10" class="row_heading level0 row10" >song_length</th>
#       <td id="T_ff735_row10_col0" class="data row10 col0" >float64</td>
#       <td id="T_ff735_row10_col1" class="data row10 col1" >60266</td>
#       <td id="T_ff735_row10_col2" class="data row10 col2" >114</td>
#       <td id="T_ff735_row10_col3" class="data row10 col3" >0.000015</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row11" class="row_heading level0 row11" >artist_name</th>
#       <td id="T_ff735_row11_col0" class="data row11 col0" >object</td>
#       <td id="T_ff735_row11_col1" class="data row11 col1" >40582</td>
#       <td id="T_ff735_row11_col2" class="data row11 col2" >114</td>
#       <td id="T_ff735_row11_col3" class="data row11 col3" >0.000015</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row12" class="row_heading level0 row12" >target</th>
#       <td id="T_ff735_row12_col0" class="data row12 col0" >int64</td>
#       <td id="T_ff735_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_ff735_row12_col2" class="data row12 col2" >0</td>
#       <td id="T_ff735_row12_col3" class="data row12 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row13" class="row_heading level0 row13" >song_id</th>
#       <td id="T_ff735_row13_col0" class="data row13 col0" >object</td>
#       <td id="T_ff735_row13_col1" class="data row13 col1" >359966</td>
#       <td id="T_ff735_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_ff735_row13_col3" class="data row13 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff735_level0_row14" class="row_heading level0 row14" >city</th>
#       <td id="T_ff735_row14_col0" class="data row14 col0" >int64</td>
#       <td id

# %% [markdown]
# Считаю, что пол, автор текста и композитор не несут значимой информации, при этом имеют большое количество пропусков, данные столбцы можно дропнуть.
#
# Столбцы isrc и source_screen_name также можем удалить, так как isrc у некоторых песен могут быть одинаковыми
#
# Так же следует удалить столбцы с датами, они нам не понадобятся.
#
# Подумаем что нужно оставить. Оставим язык, исполнителя, жанр и название песни, и возможно точку входа.

# %%
train_clear = train.copy()
target_train = train_clear['target']
train_clear = train_clear[['genre_ids', 'source_type', 'name', 'language', 'artist_name', 'song_id', 'msno']]

test_clear = test.copy()
test_clear = test_clear[['genre_ids', 'source_type', 'name', 'language', 'artist_name', 'song_id', 'msno']]

# %%
train_clear.head()
# Out:
#   genre_ids      source_type                                     name  \
# 0       359  online-playlist                               Good Grief
# 1      1259   local-playlist                       Lords of Cardboard
# 2      1259   local-playlist  Hip Hop Is Dead(Album Version (Edited))
# 3      1019   local-playlist                             Disco Africa
# 4      1011  online-playlist                        Sleep Without You
#
#    language      artist_name                                       song_id  \
# 0      52.0         Bastille  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=
# 1      52.0  Various Artists  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=
# 2      52.0              Nas  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=
# 3      -1.0         Soundway  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=
# 4      52.0      Brett Young  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=
#
#                                            msno
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=

# %% [markdown]
# Заполним строки с пропущенными цзначениями на самые часто встречаемые

# %%
values_info(train_clear)
# Out:
# <style type="text/css">
# #T_d5d08_row0_col1, #T_d5d08_row1_col1, #T_d5d08_row3_col1, #T_d5d08_row3_col2, #T_d5d08_row3_col3, #T_d5d08_row4_col2, #T_d5d08_row4_col3, #T_d5d08_row5_col2, #T_d5d08_row5_col3, #T_d5d08_row6_col2, #T_d5d08_row6_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d5d08_row0_col2, #T_d5d08_row0_col3, #T_d5d08_row5_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d5d08_row1_col2, #T_d5d08_row1_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_d5d08_row2_col1 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_d5d08_row2_col2, #T_d5d08_row2_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d5d08_row4_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_d5d08_row6_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# </style>
# <table id="T_d5d08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5d08_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_d5d08_level0_col1" class="col_heading level0 col1" >Unique Values</th>
#       <th id="T_d5d08_level0_col2" class="col_heading level0 col2" >Null Values</th>
#       <th id="T_d5d08_level0_col3" class="col_heading level0 col3" >% null Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5d08_level0_row0" class="row_heading level0 row0" >genre_ids</th>
#       <td id="T_d5d08_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_d5d08_row0_col1" class="data row0 col1" >572</td>
#       <td id="T_d5d08_row0_col2" class="data row0 col2" >118455</td>
#       <td id="T_d5d08_row0_col3" class="data row0 col3" >0.016056</td>
#     </tr>
#     <tr>
#       <th id="T_d5d08_level0_row1" class="row_heading level0 row1" >source_type</th>
#       <td id="T_d5d08_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_d5d08_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_d5d08_row1_col2" class="data row1 col2" >21539</td>
#       <td id="T_d5d08_row1_col3" class="data row1 col3" >0.002920</td>
#     </tr>
#     <tr>
#       <th id="T_d5d08_level0_row2" class="row_heading level0 row2" >name</th>
#       <td id="T_d5d08_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_d5d08_row2_col1" class="data row2 col1" >234144</td>
#       <td id="T_d5d08_row2_col2" class="data row2 col2" >1457</td>
#       <td id="T_d5d08_row2_col3" class="data row2 col3" >0.000197</td>
#     </tr>
#     <tr>
#       <th id="T_d5d08_level0_row3" class="row_heading level0 row3" >language</th>
#       <td id="T_d5d08_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_d5d08_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_d5d08_row3_col2" class="data row3 col2" >150</td>
#       <td id="T_d5d08_row3_col3" class="data row3 col3" >0.000020</td>
#     </tr>
#     <tr>
#       <th id="T_d5d08_level0_row4" class="row_heading level0 row4" >artist_name</th>
#       <td id="T_d5d08_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_d5d08_row4_col1" class="data row4 col1" >40582</td>
#       <td id="T_d5d08_row4_col2" class="data row4 col2" >114</td>
#       <td id="T_d5d08_row4_col3" class="data row4 col3" >0.000015</td>
#     </tr>
#     <tr>
#       <th id="T_d5d08_level0_row5" class="row_heading level0 row5" >song_id</th>
#       <td id="T_d5d08_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_d5d08_row5_col1" class="data row5 col1" >359966</td>
#       <td id="T_d5d08_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_d5d08_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5d08_level0_row6" class="row_heading level0 row6" >msno</th>
#       <td id="T_d5d08_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_d5d08_row6_col1" class="data row6 col1" >30755</td>
#       <td id="T_d5d08_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_d5d08_row6_col3" class="data row6 col3" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
missing_pipe = Pipeline(
    [
        (
            'simpleImputer_missing', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# %%
train_full = missing_pipe.fit_transform(train_clear)
train_full = pd.DataFrame(train_full, columns=['genre_ids', 'source_type', 'name', 'language', 'artist_name', 'song_id', 'msno'])
train_full.head()
# Out:
#   genre_ids      source_type                                     name  \
# 0       359  online-playlist                               Good Grief
# 1      1259   local-playlist                       Lords of Cardboard
# 2      1259   local-playlist  Hip Hop Is Dead(Album Version (Edited))
# 3      1019   local-playlist                             Disco Africa
# 4      1011  online-playlist                        Sleep Without You
#
#   language      artist_name                                       song_id  \
# 0     52.0         Bastille  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=
# 1     52.0  Various Artists  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=
# 2     52.0              Nas  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=
# 3     -1.0         Soundway  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=
# 4     52.0      Brett Young  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=
#
#                                            msno
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=

# %%
test_full = missing_pipe.transform(test_clear)
test_full = pd.DataFrame(test_full, columns=['genre_ids', 'source_type', 'name', 'language', 'artist_name', 'song_id', 'msno'])
test_full.head()
# Out:
#   genre_ids          source_type                                  name  \
# 0       458        local-library                                愛其實很殘忍
# 1       465        local-library                                    她說
# 2      2022  song-based-playlist                   subarashiki nichijo
# 3       465                radio  Hold Me| Thrill Me| Kiss Me| Kill Me
# 4       873                radio                               Om Yoga
#
#   language         artist_name                                       song_id  \
# 0      3.0  梁文音 (Rachel Liang)  WmHKgKMlp1lQMecNdNvDMkvIycZYHnFwDT72I5sIssc=
# 1      3.0        林俊傑 (JJ Lin)  y/rsZ9DC7FwK5F2PK2D5mj+aOBUJAjuu3dZ14NgE0vM=
# 2     17.0  Yu Takahashi (高橋優)  8eZLFOdGVdXBSqoAv5nsLigeH2BvKXzTQYtUM53I0k4=
# 3     52.0                  U2  ztCf8thYsS4YN3GcIL/bvoxLm/T5mYBVKOO4C9NiVfQ=
# 4     -1.0       Yoga Mr Sound  MKVMpslKcQhMaFEgcEQhEfi5+RZhMYlU3eRDpySrH8Y=
#
#                                            msno
# 0  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 1  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 2  /uQAlrAkaczV+nWCd2sPF2ekvXPRipV7q0l+gbLuxjw=
# 3  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 4  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=

# %%
train_full.duplicated().sum()
# Out:
# 0

# %%
train_full
# Out:
#         genre_ids      source_type                                     name  \
# 0             359  online-playlist                               Good Grief
# 1            1259   local-playlist                       Lords of Cardboard
# 2            1259   local-playlist  Hip Hop Is Dead(Album Version (Edited))
# 3            1019   local-playlist                             Disco Africa
# 4            1011  online-playlist                        Sleep Without You
# ...           ...              ...                                      ...
# 7377413      1259   local-playlist                             Still D.R.E.
# 7377414       465             song                              Locked Away
# 7377415       465             song                                  FLY OUT
# 7377416      2122  online-playlist                               Wonderwall
# 7377417       212  online-playlist                          Time after time
#
#         language                     artist_name  \
# 0           52.0                        Bastille
# 1           52.0                 Various Artists
# 2           52.0                             Nas
# 3           -1.0                        Soundway
# 4           52.0                     Brett Young
# ...          ...                             ...
# 7377413     52.0                         Dr. Dre
# 7377414     52.0      R. City feat.  Adam Levine
# 7377415      3.0  兄弟本色G.U.T.S. (姚中仁、張震嶽、頑童MJ116)
# 7377416     52.0               Brad Mehldau Trio
# 7377417     52.0     Biréli Lagrène| Sylvain Luc
#
#                                               song_id  \
# 0        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=
# 1        bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=
# 2        JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=
# 3        2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=
# 4        3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=
# ...                                               ...
# 7377413  VJTxizih/o28kXCbtPbIyWXScoXGvxyYtl6R+0YB5JM=
# 7377414  z1mqaU9YOX7T/PFDvUoWozdFq7rC3KwaQP7nFVprjMI=
# 7377415  750RprmFfLV0bymtDH88g24pLZGVi5VpBAI300P6UOA=
# 7377416  G8wgqObgeAMER/rVCIlgcNeQ8mm0CzF/GsxiMK8TTnA=
# 7377417  Ju0VGkjWeBUZCd7r5Az2hUImhMoWxWLUicOedsmvG0g=
#
#                                                  msno
# 0        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# ...                                               ...
# 7377413  6xdFzPlrasIDD95mQWXVC3Bg4ptnGYtBl4ztVEZMddU=
# 7377414  ZxbVmt3Kh/XOH+h58c2Kdj6SjFZk+wnUO006IgWzMQE=
# 7377415  ZxbVmt3Kh/XOH+h58c2Kdj6SjFZk+wnUO006IgWzMQE=
# 7377416  0aH4Hd3ziPSRHClRX8rkeOEaAG5EPPkW1mKGCdXEok0=
# 7377417  0aH4Hd3ziPSRHClRX8rkeOEaAG5EPPkW1mKGCdXEok0=
#
# [7377418 rows x 7 columns]

# %%
values_info(train_full)
# Out:
# <style type="text/css">
# #T_a87e7_row0_col1, #T_a87e7_row0_col2, #T_a87e7_row0_col3, #T_a87e7_row1_col1, #T_a87e7_row1_col2, #T_a87e7_row1_col3, #T_a87e7_row2_col2, #T_a87e7_row2_col3, #T_a87e7_row3_col1, #T_a87e7_row3_col2, #T_a87e7_row3_col3, #T_a87e7_row4_col2, #T_a87e7_row4_col3, #T_a87e7_row5_col2, #T_a87e7_row5_col3, #T_a87e7_row6_col2, #T_a87e7_row6_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a87e7_row2_col1 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_a87e7_row4_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_a87e7_row5_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a87e7_row6_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# </style>
# <table id="T_a87e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a87e7_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_a87e7_level0_col1" class="col_heading level0 col1" >Unique Values</th>
#       <th id="T_a87e7_level0_col2" class="col_heading level0 col2" >Null Values</th>
#       <th id="T_a87e7_level0_col3" class="col_heading level0 col3" >% null Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a87e7_level0_row0" class="row_heading level0 row0" >genre_ids</th>
#       <td id="T_a87e7_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_a87e7_row0_col1" class="data row0 col1" >572</td>
#       <td id="T_a87e7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a87e7_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a87e7_level0_row1" class="row_heading level0 row1" >source_type</th>
#       <td id="T_a87e7_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_a87e7_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_a87e7_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_a87e7_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a87e7_level0_row2" class="row_heading level0 row2" >name</th>
#       <td id="T_a87e7_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_a87e7_row2_col1" class="data row2 col1" >234144</td>
#       <td id="T_a87e7_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_a87e7_row2_col3" class="data row2 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a87e7_level0_row3" class="row_heading level0 row3" >language</th>
#       <td id="T_a87e7_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_a87e7_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_a87e7_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_a87e7_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a87e7_level0_row4" class="row_heading level0 row4" >artist_name</th>
#       <td id="T_a87e7_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_a87e7_row4_col1" class="data row4 col1" >40582</td>
#       <td id="T_a87e7_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_a87e7_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a87e7_level0_row5" class="row_heading level0 row5" >song_id</th>
#       <td id="T_a87e7_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_a87e7_row5_col1" class="data row5 col1" >359966</td>
#       <td id="T_a87e7_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_a87e7_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a87e7_level0_row6" class="row_heading level0 row6" >msno</th>
#       <td id="T_a87e7_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_a87e7_row6_col1" class="data row6 col1" >30755</td>
#       <td id="T_a87e7_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_a87e7_row6_col3" class="data row6 col3" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
values_info(test_full)
# Out:
# <style type="text/css">
# #T_cab6b_row0_col1, #T_cab6b_row0_col2, #T_cab6b_row0_col3, #T_cab6b_row1_col1, #T_cab6b_row1_col2, #T_cab6b_row1_col3, #T_cab6b_row2_col2, #T_cab6b_row2_col3, #T_cab6b_row3_col1, #T_cab6b_row3_col2, #T_cab6b_row3_col3, #T_cab6b_row4_col2, #T_cab6b_row4_col3, #T_cab6b_row5_col2, #T_cab6b_row5_col3, #T_cab6b_row6_col2, #T_cab6b_row6_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_cab6b_row2_col1 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_cab6b_row4_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_cab6b_row5_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_cab6b_row6_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# </style>
# <table id="T_cab6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cab6b_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_cab6b_level0_col1" class="col_heading level0 col1" >Unique Values</th>
#       <th id="T_cab6b_level0_col2" class="col_heading level0 col2" >Null Values</th>
#       <th id="T_cab6b_level0_col3" class="col_heading level0 col3" >% null Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cab6b_level0_row0" class="row_heading level0 row0" >genre_ids</th>
#       <td id="T_cab6b_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_cab6b_row0_col1" class="data row0 col1" >501</td>
#       <td id="T_cab6b_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_cab6b_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cab6b_level0_row1" class="row_heading level0 row1" >source_type</th>
#       <td id="T_cab6b_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_cab6b_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_cab6b_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_cab6b_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cab6b_level0_row2" class="row_heading level0 row2" >name</th>
#       <td id="T_cab6b_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_cab6b_row2_col1" class="data row2 col1" >154716</td>
#       <td id="T_cab6b_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_cab6b_row2_col3" class="data row2 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cab6b_level0_row3" class="row_heading level0 row3" >language</th>
#       <td id="T_cab6b_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_cab6b_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_cab6b_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_cab6b_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cab6b_level0_row4" class="row_heading level0 row4" >artist_name</th>
#       <td id="T_cab6b_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_cab6b_row4_col1" class="data row4 col1" >27563</td>
#       <td id="T_cab6b_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_cab6b_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cab6b_level0_row5" class="row_heading level0 row5" >song_id</th>
#       <td id="T_cab6b_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_cab6b_row5_col1" class="data row5 col1" >224753</td>
#       <td id="T_cab6b_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_cab6b_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cab6b_level0_row6" class="row_heading level0 row6" >msno</th>
#       <td id="T_cab6b_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_cab6b_row6_col1" class="data row6 col1" >25131</td>
#       <td id="T_cab6b_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_cab6b_row6_col3" class="data row6 col3" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
list_columns = ['genre_ids', 'source_type', 'name', 'language', 'artist_name']
for name in list_columns:
    train_full[name] = train_full[name].astype(str)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Создание матрицы TF-IDF на основе текстовых признаков
text_features = ['genre_ids', 'source_type', 'name', 'language', 'artist_name']
text_data = train_full[text_features].apply(lambda x: ' '.join(x), axis=1)
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(text_data)

# %%
# Функция рекомендации на основе схожести между пользователями
def recommend(user_id, num_recommendations=20):
    user_index = train_full[train_full['msno'] == user_id].index[0]
    user_profile = tfidf_matrix[user_index]
    similarity_scores = cosine_similarity(tfidf_matrix, user_profile)
    similar_users = similarity_scores.argsort(axis=0)[::-1][:num_recommendations].flatten()
    recommended_songs = []
    for index in similar_users:
        if index != user_index and train_full.iloc[index]['song_id'] not in recommended_songs:
            recommended_songs.append(train_full.iloc[index]['song_id'])
    return recommended_songs

# %%
import random

# %%
# Пример использования:
user_id = random.choice(test_full['msno'])
recommendations = recommend(user_id)
print("Рекомендации для пользователя", user_id, ":", recommendations)
# Out:
# Рекомендации для пользователя dltpI9IaXapOUbDzGoTeUz2zY4F70jC7D+wdrcgZA7c= : ['sDa4M+ukVOvZHES+jdGCnjRkpIGr4TJv5I5fn//3FTM=']

# %%
# Создаем пустой словарь
songs_dict = {}

# Итерируемся по строкам DataFrame
for index, row in train_full.iterrows():
    # Получаем значения признаков
    song_id = row['song_id']
    genre_ids = row['genre_ids']
    source_type = row['source_type']
    name = row['name']
    language = row['language']
    artist_name = row['artist_name']
    
    # Добавляем данные в словарь с использованием song_id в качестве ключа
    songs_dict[song_id] = {
        'genre_ids': genre_ids,
        'source_type': source_type,
        'name': name,
        'language': language,
        'artist_name': artist_name
    }

# Выводим первый элемент словаря в качестве примера
print(songs_dict[next(iter(songs_dict))])
# Out:
# {'genre_ids': '359', 'source_type': 'radio', 'name': 'Good Grief', 'language': '52.0', 'artist_name': 'Bastille'}

# %%
songs_dict['mJjY3Aq2ziKriR8beib4g7okk6qwf2BPK5rd/g7lF7Q=']
# Out:
# {'genre_ids': '465',
#  'source_type': 'top-hits-for-artist',
#  'name': '這是你的歌',
#  'language': '3.0',
#  'artist_name': '周湯豪 (NICKTHEREAL)'}

# %%
songs_dict['AlEP3SDleCdt6gP1jxB7GZPch277MfWzxFaZ8xIZLsA=']
# Out:
# {'genre_ids': '444',
#  'source_type': 'top-hits-for-artist',
#  'name': 'Baboya',
#  'language': '31.0',
#  'artist_name': 'Kim Jong Kook'}
